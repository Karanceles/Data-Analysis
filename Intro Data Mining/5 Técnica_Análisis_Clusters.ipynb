# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=3, random_state=42) # n_clusters or categories (versicolor, virginica, setosa)
# random state for an equal value to everyone
df = sns.load_dataset("iris")
df["cluster"] = model.fit_predict(df.iloc[:,:-1]) # new column
df
# Out:
# c:\Users\lcsvi\OneDrive\Escritorio\Pyth\Data Analysis\datos\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#      sepal_length  sepal_width  petal_length  petal_width    species  cluster
# 0             5.1          3.5           1.4          0.2     setosa        1
# 1             4.9          3.0           1.4          0.2     setosa        1
# 2             4.7          3.2           1.3          0.2     setosa        1
# 3             4.6          3.1           1.5          0.2     setosa        1
# 4             5.0          3.6           1.4          0.2     setosa        1
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica        2
# ...

# %%
# no longer hue = species but cluster
sns.scatterplot(data=df, x="sepal_length", y = "petal_length", hue = "cluster")
plt.show()

# %%
# our predictions weren't so precise, but that't 'cause the code itself isn't
# so, in order to avoid errors in our model, we need to analyze and correct
# this is why evaluation is so important in data analysis
