# %%
import matplotlib.pyplot as plt

# %%
# Example of a single line
x = [0, 1, 2, 3, 4, 5]
y = [0, 1, 2, 3, 4, 5]

plt.plot(x,y)
plt.scatter(x,y) # plot with points of interest
plt.xlabel("Eje X") # naming axis
plt.ylabel("Eje Y")
plt.title("Mi primera gráfica")
plt.show() # shows and enlarges in a screen idk really
