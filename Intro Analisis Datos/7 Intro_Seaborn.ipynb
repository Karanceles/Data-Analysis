# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# random dataset from library
data = sns.load_dataset("iris") 
data, set(data["species"])
# Out:
# (     sepal_length  sepal_width  petal_length  petal_width    species
#  0             5.1          3.5           1.4          0.2     setosa
#  1             4.9          3.0           1.4          0.2     setosa
#  2             4.7          3.2           1.3          0.2     setosa
#  3             4.6          3.1           1.5          0.2     setosa
#  4             5.0          3.6           1.4          0.2     setosa
#  ..            ...          ...           ...          ...        ...
#  145           6.7          3.0           5.2          2.3  virginica
#  146           6.3          2.5           5.0          1.9  virginica
#  147           6.5          3.0           5.2          2.0  virginica
#  148           6.2          3.4           5.4          2.3  virginica
#  149           5.9          3.0           5.1          1.8  virginica
#
#  [150 rows x 5 columns],
#  {'setosa', 'versicolor', 'virginica'})

# %%
# Dispersion graph
sns.scatterplot(x="sepal_length", y ="sepal_width", hue="species", data=data)
plt.xlabel("Sepal Lenght")
plt.ylabel("Sepal Width")
plt.title("Iris Species Dimentions Graph")
plt.show()

# %%
# Ridgeplot graphic

setosa = data[data["species"] == "setosa"]
versicolor = data[data["species"] == "versicolor"]
virginica = data[data["species"] == "virginica"]

fig, ax = plt.subplots(figsize=(8,6)) # resize and shaping axis
plt.xlabel("Petal Length")

# Create ridgeplot using kdeplot
sns.kdeplot(data=setosa["petal_length"], label="setosa", ax = ax, fill=True)
sns.kdeplot(data=versicolor["petal_length"], label="versicolor", ax = ax, fill=True)
sns.kdeplot(data=virginica["petal_length"], label="virginica", ax = ax, fill=True)

# adjusting legend's position
ax.legend(loc="upper right")    

plt.title("Ridgeplot - Iris dataset")
# Out:
# Text(0.5, 1.0, 'Ridgeplot - Iris dataset')

# %%
# same 1st dispersion graph but beautyfied
sns.set_style("whitegrid")
palette = sns.color_palette("husl", 3) # color palette

sns.scatterplot(x="sepal_length", y = "sepal_width", hue="species", data=data, palette=palette)
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.title("Dispersion graph")
plt.show()
